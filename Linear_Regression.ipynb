# %% [markdown]
# # Linear Regression Practical impplmentation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing()

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
dataset = pd.DataFrame(df.data)

# %%
dataset.columns = df.feature_names

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Dependent feature and Undependent feature

X = dataset
y = df.target

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
#train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.30, random_state = 42
)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# ...

# %% [raw]
# Using fit_transform() on the training data allows the scaler or transformer to learn parameters (such as mean, standard deviation, or category encodings)
# directly from the training set while simultaneously applying the transformation. This step is essential because the model needs to understand the distribution of the training data to function correctly.
#
# Applying transform() to the test data ensures that the same parameters learned from the training set are used to scale or encode the test data,
# without revealing any information about the test distribution to the training process.  If fit_transform() were used on the test set,
# the model would compute new statistics (like a different mean or variance) based on the test data, effectively "cheating" by accessing future information.  This practice would lead to data leakage,
# resulting in overfitting and overly optimistic performance metrics that do not reflect real-world generalization.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]])

# %%
#for getting the same value as earlier use  scaler.inverse_transform()
scaler.inverse_transform(X_train)
# Out:
# array([[   4.1312    ,   35.        ,    5.88235294, ...,    2.98529412,
#           33.93      , -118.02      ],
#        [   2.8631    ,   20.        ,    4.40120968, ...,    2.0141129 ,
#           32.79      , -117.09      ],
#        [   4.2026    ,   24.        ,    5.61754386, ...,    2.56491228,
#           34.59      , -120.14      ],
#        ...,
#        [   2.9344    ,   36.        ,    3.98671727, ...,    3.33206831,
#           34.03      , -118.38      ],
#        [   5.7192    ,   15.        ,    6.39534884, ...,    3.17889088,
#           37.58      , -121.96      ],
#        [   2.5755    ,   52.        ,    3.40257649, ...,    2.10869565,
#           37.77      , -122.42      ]])

# %%
from sklearn.linear_model import LinearRegression
#Cross Validation
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [raw]
# The output of cross-validation (e.g., from cross_val_score) tells you how well your model performs on different subsets of your data — it’s essentially a reliability check for your model’s performance.
#
# The variation between scores shows how stable your model is across different subsets of the data.
# The mean score is your average expected performance on unseen data.
# The standard deviation tells you how much the performance changes depending on the data split (lower is better).
#
# Meaning:
# High mean score + low std deviation → Model is accurate and consistent.
# High mean score + high std deviation → Model is accurate but unstable (may overfit).
# Low mean score → Model underperforms regardless of stability.
#
# ✅ In short:
# The output of cross-validation tells you how your model is likely to perform on unseen data and how stable that performance is across different data splits.

# %%
mse =  cross_val_score(regression, X_train, y_train, scoring="neg_mean_squared_error", cv=5)

# %%
mse
# Out:
# array([-0.54787556, -0.500835  , -0.52045639, -0.51612252, -0.54883741])

# %%
np.mean(mse)
# Out:
# np.float64(-0.5268253746355749)

# %%
reg_predict = regression.predict(X_test)

# %%
reg_predict
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133])

# %%
y_test
# Out:
# array([0.477  , 0.458  , 5.00001, ..., 2.184  , 1.194  , 2.098  ])

# %%
import seaborn as sns
sns.displot(reg_predict - y_test, kind = 'kde')

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(reg_predict, y_test)

# %%
score
# Out:
# 0.3451339380943981

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge = Ridge()
params = {'alpha' : [1e-15, 1e-10, 1e-5, 3, 8, 10, 20]}

ridge_regressor = GridSearchCV(ridge, params, scoring='neg_mean_squared_error', cv=5)
ridge_regressor.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-05, 3, 8, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 8}
# -0.5268179681302126

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso = Lasso()
params = {'alpha' : [1e-15, 1e-10, 1e-5, 3, 8, 10, 20, 30, 45, 50]}
lasso_regressor = GridSearchCV(lasso, params, scoring='neg_mean_absolute_error', cv=5)
lasso_regressor.fit(X_train, y_train)
# Out:
# c:\Users\soura\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.790e+00, tolerance: 1.570e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-05, 3, 8, 10, 20, 30, 45,
#                                    50]},
#              scoring='neg_mean_absolute_error')

# %%
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 1e-05}
# -0.5318807742191876

# %%
# predict lasso with a fixed alpha( without hypertuning the alpha value )
lasso.fit(X_train, y_train)
lasso.predict(X_test)
# Out:
# array([2.06923961, 2.06923961, 2.06923961, ..., 2.06923961, 2.06923961,
#        2.06923961])

# %%
y_test
# Out:
# array([0.477  , 0.458  , 5.00001, ..., 2.184  , 1.194  , 2.098  ])

# %%
lasso_pred = lasso_regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(lasso_pred, y_test)

# %%
score
# Out:
# 0.34508586410435604

# %%
sns.displot(y_test-lasso_pred, kind='ecdf')
